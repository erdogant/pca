# %% [markdown]
# <!-- Centered logo -->
# <p align="center">
#   <img src="https://github.com/erdogant/pca/blob/master/docs/figs/logo.png?raw=true" width="400" />
# </p>
#
# <!-- Badges row (centered) -->
# <p align="center">
#   <a href="https://img.shields.io/pypi/pyversions/pca"><img src="https://img.shields.io/pypi/pyversions/pca" /></a>
#   <a href="https://pypi.org/project/pca/"><img src="https://img.shields.io/pypi/v/bnlearn" /></a>
#   <img src="https://img.shields.io/github/stars/erdogant/pca" />
#   <a href="https://github.com/erdogant/pca/blob/master/LICENSE"><img src="https://img.shields.io/badge/license-MIT-green.svg" /></a>
#   <a href="https://github.com/erdogant/pca/network"><img src="https://img.shields.io/github/forks/erdogant/pca.svg" /></a>
#   <a href="https://github.com/erdogant/pca/issues"><img src="https://img.shields.io/github/issues/erdogant/pca.svg" /></a>
#   <a href="http://www.repostatus.org/#active"><img src="http://www.repostatus.org/badges/latest/active.svg" /></a>
#   <a href="https://pepy.tech/project/pca/"><img src="https://pepy.tech/badge/pca/month" /></a>
#   <a href="https://pepy.tech/project/pca/"><img src="https://pepy.tech/badge/pca" /></a>
#   <a href="https://zenodo.org/badge/latestdoi/231263493"><img src="https://zenodo.org/badge/231263493.svg" /></a>
#   <a href="https://erdogant.github.io/pca/"><img src="https://img.shields.io/badge/Sphinx-Docs-Green" /></a>
#   <a href="https://erdogant.github.io/bnlearn/pages/html/Documentation.html#medium-blog"><img src="https://img.shields.io/badge/Medium-Blog-black" /></a>
#   <img src="https://img.shields.io/github/repo-size/erdogant/pca" />
#   <a href="https://erdogant.github.io/bnlearn/pages/html/Documentation.html#"><img src="https://img.shields.io/badge/Support%20this%20project-grey.svg?logo=github%20sponsors" /></a>
#   <a href="https://erdogant.github.io/pca/pages/html/Documentation.html#colab-notebook"><img src="https://colab.research.google.com/assets/colab-badge.svg" /></a>
# </p>
#
# ---
#
# # pca
#
# Principal Component Analysis is the most well-known technique for (big) data analysis. However, interpretation of the variance in the low-dimensional space can remain challenging. Understanding the loadings and interpreting the biplot is a must-know part for anyone who uses PCA.  ⭐️Star it if you like it⭐️
#
# ---
#
# ## Core functionalities:
#
# | Feature | Description |
# |--------|-------------|
# | [**Fit and Transform**](https://erdogant.github.io/pca/pages/html/Algorithm.html) | Perform the PCA analysis. |
# | [**Biplot and Loadings**](https://erdogant.github.io/pca/pages/html/Plots.html#biplot) | Make Biplot with the loadings. |
# | [**Explained Variance**](https://erdogant.github.io/pca/pages/html/Plots.html#explained-variance-plot) | Determine the explained variance and plot. |
# | [**Best Performing Features**](https://erdogant.github.io/pca/pages/html/Algorithm.html#best-performing-features) | Extract the best performing features. |
# | [**Scatterplot**](https://erdogant.github.io/pca/pages/html/Plots.html#scatter-plot) | Create scaterplot with loadings. |
# | [**Outlier Detection**](https://erdogant.github.io/pca/pages/html/Outlier%20detection.html) | Detect outliers using Hotelling T2 and/or SPE/Dmodx. |
# | [**Normalize out Variance**](https://erdogant.github.io/pca/pages/html/Examples.html#normalizing-out-pcs) | Remove any bias from your data. |
# | [**Save and load**](https://erdogant.github.io/pca/pages/html/save.html) | Save and load models. |
# | [**Analyze discrete datasets**](https://erdogant.github.io/pca/pages/html/Examples.html#analyzing-discrete-datasets) | Analyze discrete datasets. |
#
# ---
#
# <style>
# .card-container {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 16px;
#   justify-content: center;
#   margin-top: 20px;
# }
#
# .card {
#   flex: 1 1 300px;
#   max-width: 300px;
#   background: #f9f9f9;
#   border: 1px solid #ddd;
#   border-radius: 12px;
#   padding: 16px;
#   box-shadow: 2px 2px 10px rgba(0,0,0,0.05);
#   transition: 0.3s;
# }
#
# .card:hover {
#   transform: scale(1.02);
#   box-shadow: 4px 4px 20px rgba(0,0,0,0.1);
# }
#
# .card a {
#   text-decoration: none;
#   font-weight: bold;
#   color: #333;
#   font-size: 16px;
# }
#
# .card a:hover {
#   color: #1e90ff;
# }
# </style>
#
#
# ---
#
# ### Support
# * This library is for <b>free</b> but improvements and new functionalities are made using coffee! :)
#
# * You can also [support](https://erdogant.github.io/pca/pages/html/Documentation.html) in various other ways, have a look at the [sponser page](https://erdogant.github.io/bnlearn/pages/html/Documentation.html).
#
# * Report bugs, issues and feature extensions at [github page](https://github.com/erdogant/bnlearn).
#
#
# <table>
#   <tr>
#     <td style="text-align: center;">
#       <a href="https://www.buymeacoffee.com/erdogant">
#         <img src="https://img.buymeacoffee.com/button-api/?text=Buy me a coffee&emoji=&slug=erdogant&button_colour=FFDD00&font_colour=000000&font_family=Cookie&outline_colour=000000&coffee_colour=ffffff" />
#       </a>
#     </td>
#     <td style="text-align: center;">
#       <a href="https://erdogant.medium.com/subscribe" target="_blank">
#         <img height="50" style="border:0px;height:36px;" src="https://erdogant.github.io/images/medium_follow_me.jpg" border="0" alt="Follow me on Medium" />
#       </a>
#     </td>
#   </tr>
# </table>
#
# ---

# %% [markdown]
# # Installation
#
# It is advised to install the stable version from PyPi. It is also possible to install from github source but this version can be onstable.

# %% [markdown]
# ### Install from PyPi:
#
# ```
# pip install pca
# ```

# %% [markdown]
# ### Install locally:
#
# ```
# pip install git+https://github.com/erdogant/pca
# ```

# %% [markdown]
# ### Install on Google Colaboratory:
#
#
# ```
# !pip install -e "git+https://github.com/erdogant/pca"
# ```
#
# Then **restart the runtime** (Runtime -> Restart Runtime) before importing prettymaps

# %% [markdown]
# # Tutorial

# %% [markdown]
# Check the version

# %%
# Install pca using pip:
# !pip install -U pca

# %%
import pca
print(pca.__version__)
# Out:
# 2.10.0

# %% [markdown]
# Import the pca library

# %%
from pca import pca
import numpy as np
import pandas as pd

# %% [markdown]
# Here we will create a random dataset.

# %%
# Dataset
from sklearn.datasets import load_iris
X = pd.DataFrame(data=load_iris().data, columns=load_iris().feature_names, index=load_iris().target)

# %% [markdown]
# Initialize using specified parameters. The parameters here are the default parameters.

# %%
# Initialize
model = pca(n_components=3, normalize=True)

# %%
# Fit transform
out = model.fit_transform(X)
# Out:
# [16-08-2025 08:55:29] [pca.pca] [INFO] Extracting column labels from dataframe.
# [16-08-2025 08:55:29] [pca.pca] [INFO] Extracting row labels from dataframe.
# [16-08-2025 08:55:29] [pca.pca] [INFO] Normalizing input data per feature (zero mean and unit variance)..
# [16-08-2025 08:55:29] [pca.pca] [INFO] The PCA reduction is performed on the 4 columns of the input dataframe.
# [16-08-2025 08:55:29] [pca.pca] [INFO] Fit using PCA.
# [16-08-2025 08:55:29] [pca.pca] [INFO] Compute loadings and PCs.
# [16-08-2025 08:55:29] [pca.pca] [INFO] Compute explained variance.
# [16-08-2025 08:55:29] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[3]
# [16-08-2025 08:55:29] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [16-08-2025 08:55:29] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]

# %%
# Make plot with only the directions (no scatter)
fig, ax = model.biplot(legend=False, figsize=(20, 12), dpi=50, cmap='Set1')
# Out:
# [16-08-2025 08:55:29] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [16-08-2025 08:55:29] [scatterd.scatterd] [INFO] Create scatterplot

# %%
# Make plot with only the directions (no scatter)
fig, ax = model.biplot(cmap=None, legend=False, figsize=(20, 12), dpi=50)
# Out:
# [16-08-2025 08:55:51] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [16-08-2025 08:55:52] [scatterd.scatterd] [INFO] Create scatterplot

# %%
from pca import pca
# Load example data
from sklearn.datasets import load_iris
X = pd.DataFrame(data=load_iris().data, columns=load_iris().feature_names, index=load_iris().target)

# %%
# Initialize
model = pca(n_components=3)
# Fit using PCA
results = model.fit_transform(X)
# Out:
# [16-08-2025 08:56:01] [pca.pca] [INFO] Extracting column labels from dataframe.
# [16-08-2025 08:56:01] [pca.pca] [INFO] Extracting row labels from dataframe.
# [16-08-2025 08:56:01] [pca.pca] [INFO] The PCA reduction is performed on the 4 columns of the input dataframe.
# [16-08-2025 08:56:01] [pca.pca] [INFO] Fit using PCA.
# [16-08-2025 08:56:01] [pca.pca] [INFO] Compute loadings and PCs.
# [16-08-2025 08:56:01] [pca.pca] [INFO] Compute explained variance.
# [16-08-2025 08:56:01] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[3]
# [16-08-2025 08:56:01] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [16-08-2025 08:56:01] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]

# %%
# Make plots

# Scree plot
fig, ax = model.plot(figsize=(10, 6))

# Scatter plot
fig, ax = model.scatter(figsize=(10, 6))

# Biplot
fig, ax = model.biplot(figsize=(10, 6), cmap='Set1')
# Out:
# [16-08-2025 08:56:52] [scatterd.scatterd] [INFO] Create scatterplot
# [16-08-2025 08:56:52] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [16-08-2025 08:56:52] [scatterd.scatterd] [INFO] Create scatterplot

# %%
# Coloring on density to focus on the core samples.

# Biplot
fig, ax = model.biplot(figsize=(20, 12), dpi=50, gradient='#ffffff', cmap='Set1')
# Out:
# [16-08-2025 08:56:57] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [16-08-2025 08:56:57] [scatterd.scatterd] [INFO] Create scatterplot

# %%
# Outliers are stored in results:
results['outliers']

# Outliers based on T2
print('--------T2------------')
print(results['outliers'].loc[results['outliers']['y_bool'], :])

# Outliers based on SPE
print('--------SPE------------')
print(results['outliers'].loc[results['outliers']['y_bool_spe'], :])
# Out:
# --------T2------------
# Empty DataFrame
# Columns: [y_proba, p_raw, y_score, y_bool, y_bool_spe, y_score_spe]
# Index: []
# --------SPE------------
#     y_proba     p_raw    y_score  y_bool  y_bool_spe  y_score_spe
# 2  0.845006  0.054265  12.366968   False        True     3.510781

# %%
# Outlier detection
fig, ax = model.biplot(SPE=True, HT2=True, figsize=(20, 12), dpi=50, cmap='Set1')
# Out:
# [16-08-2025 08:56:02] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [16-08-2025 08:56:02] [scatterd.scatterd] [INFO] Create scatterplot
# [16-08-2025 08:56:02] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]

# %%
# 3D plots
fig, ax = model.scatter3d(figsize=(20, 12), dpi=50)
fig, ax = model.biplot3d(figsize=(20, 12), dpi=50, cmap='Set1')
fig, ax = model.biplot3d(SPE=True, HT2=True, figsize=(20, 12), dpi=50, cmap='Set1')
# Out:
# [16-08-2025 08:56:04] [scatterd.scatterd] [INFO] Create scatterplot
# [16-08-2025 08:56:04] [pca.pca] [INFO] Plot PC1 vs PC2 vs PC3 with loadings.
# [16-08-2025 08:56:04] [scatterd.scatterd] [INFO] Create scatterplot
# [16-08-2025 08:56:04] [pca.pca] [INFO] Plot PC1 vs PC2 vs PC3 with loadings.
# [16-08-2025 08:56:04] [scatterd.scatterd] [INFO] Create scatterplot

# %%
fig, ax = model.biplot3d(SPE=True, HT2=True, visible=False, figsize=(20, 12), dpi=50, cmap='Set1')

# Set the figure again to True and show the figure.
fig.set_visible(True)
fig
# Out:
# [16-08-2025 08:56:05] [pca.pca] [INFO] Plot PC1 vs PC2 vs PC3 with loadings.
# [16-08-2025 08:56:05] [scatterd.scatterd] [INFO] Create scatterplot

# %%
# Normalize out PCs
X_norm = model.norm(X)
# Out:
# [16-08-2025 08:56:06] [pca.pca] [INFO] Cleaning previous fitted model results...
# [16-08-2025 08:56:06] [pca.pca] [INFO] Column labels are auto-completed.
# [16-08-2025 08:56:06] [pca.pca] [INFO] Row labels are auto-completed.
# [16-08-2025 08:56:06] [pca.pca] [INFO] The PCA reduction is performed on the 4 columns of the input dataframe.
# [16-08-2025 08:56:06] [pca.pca] [INFO] Fit using PCA.
# [16-08-2025 08:56:06] [pca.pca] [INFO] Compute loadings and PCs.
# [16-08-2025 08:56:06] [pca.pca] [INFO] Compute explained variance.
# [16-08-2025 08:56:06] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[4]
# [16-08-2025 08:56:06] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [16-08-2025 08:56:06] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]

# %%
print(X_norm)
# Out:
# [[2.49990054 2.78788045 2.74007787 2.46298105]
#  [2.24514218 2.27477466 2.30717588 2.60721244]
#  [2.38474057 2.23955287 2.27559719 2.40280376]
#  [2.37686142 2.11782337 2.1208399  2.37966584]
#  [2.57760183 2.77759013 2.71880048 2.35613751]
#  [2.92317117 3.36387351 3.29289924 2.51380226]
#  [2.63624098 2.31860119 2.36489273 2.29357275]
#  [2.47621719 2.6515098  2.59629664 2.44912153]
#  [2.28208213 1.80115864 1.86620565 2.37978201]
#  [2.2201403  2.35543978 2.2861786  2.48878069]
#  [2.57557295 3.18519624 3.07175338 2.51857721]
#  [2.53023513 2.50484883 2.43123804 2.32841847]
#  [2.16484856 2.18978684 2.16434951 2.49347798]
#  [2.21297034 1.74260812 1.81207136 2.24275154]
#  [2.62751613 3.67495923 3.58013832 2.6158681 ]
#  [3.12721426 3.92834807 3.82479462 2.44383999]
#  [2.85995438 3.30530893 3.3368035  2.55091586]
#  [2.59930103 2.79221721 2.80586297 2.52100318]
#  [2.70785564 3.53112919 3.40247405 2.67404832]
#  [2.79088849 3.01794056 2.96217857 2.35833115]
# ...
